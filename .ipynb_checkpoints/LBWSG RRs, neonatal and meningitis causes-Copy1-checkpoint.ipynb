# %% [markdown]
# # Note: the dataframe to run this notebook has now changed because we changed the model structure where LBWSG to affect ACMR

# %%
# !whoami
# !date
# Out:
# nicoly
# Tue Sep 22 15:19:42 PDT 2020

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
store = pd.HDFStore('/share/costeffectiveness/artifacts/vivarium_gates_bep/india.hdf')
#this file is where everything for LBWSG is by country

# %%
store.keys()
# Out:
# ['/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_0',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_1',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_10',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_100',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_101',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_102',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_103',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_104',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_105',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_106',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_107',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_108',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_109',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_11',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_110',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_111',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_112',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_113',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_114',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_115',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_116',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_117',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_118',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_119',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_12',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_120',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_121',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_122',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_123',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_124',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_125',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_126',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_127',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_128',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_129',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_13',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_130',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_131',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_132',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_133',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_134',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_135',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_136',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_137',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_138',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_139',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_14',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_140',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_141',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_142',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_143',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_144',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_145',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_146',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_147',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_148',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_149',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_15',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_150',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_151',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_152',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_153',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_154',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_155',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_156',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_157',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_158',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_159',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_16',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_160',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_161',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_162',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_163',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_164',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_165',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_166',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_167',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_168',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_169',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_17',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_170',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_171',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_172',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_173',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_174',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_175',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_176',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_177',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_178',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_179',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_18',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_180',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_181',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_182',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_183',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_184',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_185',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_186',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_187',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_188',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_189',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_19',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_190',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_191',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_192',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_193',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_194',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_195',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_196',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_197',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_198',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_199',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_2',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_20',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_200',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_201',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_202',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_203',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_204',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_205',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_206',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_207',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_208',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_209',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_21',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_210',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_211',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_212',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_213',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_214',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_215',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_216',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_217',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_218',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_219',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_22',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_220',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_221',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_222',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_223',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_224',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_225',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_226',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_227',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_228',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_229',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_23',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_230',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_231',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_232',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_233',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_234',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_235',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_236',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_237',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_238',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_239',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_24',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_240',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_241',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_242',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_243',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_244',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_245',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_246',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_247',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_248',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_249',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_25',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_250',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_251',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_252',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_253',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_254',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_255',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_256',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_257',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_258',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_259',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_26',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_260',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_261',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_262',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_263',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_264',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_265',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_266',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_267',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_268',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_269',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_27',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_270',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_271',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_272',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_273',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_274',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_275',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_276',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_277',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_278',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_279',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_28',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_280',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_281',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_282',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_283',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_284',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_285',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_286',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_287',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_288',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_289',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_29',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_290',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_291',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_292',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_293',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_294',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_295',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_296',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_297',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_298',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_299',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_3',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_30',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_300',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_301',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_302',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_303',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_304',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_305',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_306',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_307',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_308',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_309',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_31',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_310',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_311',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_312',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_313',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_314',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_315',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_316',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_317',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_318',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_319',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_32',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_320',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_321',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_322',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_323',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_324',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_325',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_326',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_327',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_328',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_329',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_33',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_330',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_331',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_332',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_333',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_334',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_335',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_336',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_337',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_338',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_339',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_34',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_340',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_341',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_342',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_343',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_344',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_345',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_346',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_347',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_348',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_349',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_35',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_350',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_351',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_352',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_353',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_354',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_355',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_356',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_357',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_358',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_359',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_36',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_360',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_361',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_362',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_363',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_364',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_365',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_366',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_367',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_368',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_369',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_37',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_370',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_371',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_372',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_373',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_374',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_375',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_376',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_377',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_378',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_379',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_38',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_380',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_381',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_382',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_383',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_384',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_385',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_386',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_387',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_388',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_389',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_39',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_390',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_391',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_392',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_393',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_394',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_395',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_396',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_397',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_398',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_399',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_4',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_40',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_400',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_401',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_402',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_403',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_404',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_405',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_406',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_407',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_408',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_409',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_41',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_410',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_411',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_412',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_413',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_414',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_415',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_416',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_417',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_418',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_419',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_42',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_420',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_421',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_422',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_423',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_424',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_425',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_426',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_427',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_428',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_429',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_43',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_430',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_431',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_432',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_433',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_434',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_435',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_436',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_437',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_438',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_439',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_44',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_440',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_441',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_442',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_443',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_444',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_445',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_446',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_447',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_448',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_449',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_45',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_450',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_451',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_452',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_453',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_454',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_455',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_456',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_457',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_458',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_459',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_46',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_460',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_461',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_462',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_463',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_464',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_465',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_466',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_467',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_468',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_469',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_47',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_470',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_471',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_472',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_473',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_474',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_475',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_476',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_477',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_478',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_479',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_48',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_480',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_481',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_482',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_483',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_484',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_485',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_486',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_487',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_488',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_489',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_49',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_490',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_491',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_492',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_493',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_494',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_495',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_496',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_497',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_498',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_499',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_5',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_50',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_500',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_501',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_502',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_503',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_504',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_505',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_506',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_507',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_508',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_509',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_51',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_510',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_511',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_512',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_513',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_514',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_515',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_516',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_517',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_518',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_519',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_52',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_520',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_521',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_522',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_523',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_524',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_525',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_526',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_527',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_528',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_529',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_53',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_530',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_531',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_532',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_533',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_534',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_535',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_536',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_537',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_538',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_539',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_54',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_540',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_541',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_542',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_543',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_544',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_545',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_546',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_547',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_548',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_549',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_55',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_550',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_551',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_552',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_553',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_554',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_555',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_556',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_557',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_558',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_559',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_56',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_560',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_561',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_562',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_563',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_564',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_565',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_566',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_567',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_568',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_569',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_57',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_570',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_571',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_572',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_573',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_574',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_575',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_576',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_577',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_578',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_579',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_58',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_580',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_581',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_582',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_583',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_584',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_585',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_586',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_587',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_588',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_589',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_59',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_590',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_591',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_592',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_593',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_594',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_595',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_596',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_597',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_598',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_599',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_6',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_60',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_600',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_601',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_602',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_603',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_604',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_605',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_606',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_607',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_608',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_609',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_61',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_610',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_611',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_612',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_613',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_614',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_615',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_616',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_617',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_618',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_619',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_62',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_620',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_621',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_622',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_623',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_624',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_625',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_626',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_627',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_628',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_629',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_63',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_630',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_631',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_632',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_633',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_634',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_635',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_636',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_637',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_638',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_639',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_64',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_640',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_641',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_642',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_643',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_644',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_645',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_646',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_647',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_648',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_649',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_65',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_650',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_651',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_652',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_653',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_654',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_655',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_656',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_657',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_658',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_659',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_66',
# ...
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_812',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_813',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_814',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_815',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_816',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_817',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_818',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_819',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_82',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_820',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_821',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_822',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_823',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_824',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_825',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_826',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_827',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_828',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_829',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_83',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_830',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_831',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_832',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_833',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_834',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_835',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_836',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_837',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_838',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_839',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_84',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_840',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_841',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_842',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_843',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_844',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_845',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_846',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_847',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_848',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_849',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_85',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_850',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_851',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_852',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_853',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_854',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_855',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_856',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_857',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_858',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_859',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_86',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_860',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_861',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_862',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_863',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_864',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_865',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_866',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_867',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_868',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_869',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_87',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_870',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_871',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_872',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_873',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_874',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_875',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_876',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_877',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_878',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_879',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_88',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_880',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_881',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_882',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_883',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_884',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_885',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_886',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_887',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_888',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_889',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_89',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_890',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_891',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_892',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_893',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_894',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_895',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_896',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_897',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_898',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_899',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_9',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_90',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_900',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_901',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_902',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_903',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_904',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_905',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_906',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_907',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_908',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_909',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_91',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_910',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_911',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_912',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_913',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_914',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_915',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_916',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_917',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_918',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_919',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_92',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_920',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_921',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_922',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_923',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_924',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_925',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_926',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_927',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_928',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_929',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_93',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_930',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_931',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_932',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_933',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_934',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_935',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_936',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_937',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_938',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_939',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_94',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_940',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_941',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_942',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_943',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_944',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_945',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_946',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_947',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_948',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_949',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_95',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_950',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_951',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_952',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_953',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_954',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_955',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_956',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_957',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_958',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_959',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_96',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_960',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_961',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_962',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_963',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_964',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_965',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_966',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_967',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_968',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_969',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_97',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_970',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_971',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_972',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_973',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_974',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_975',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_976',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_977',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_978',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_979',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_98',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_980',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_981',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_982',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_983',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_984',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_985',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_986',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_987',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_988',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_989',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_99',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_990',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_991',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_992',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_993',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_994',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_995',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_996',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_997',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_998',
#  '/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_999',
#  ...]

# %%
index = store.get('/risk_factor/low_birth_weight_and_short_gestation/relative_risk/index')
index.head()

#the unique values in affected_entity is now 'all'. THis is a change when we decided to model LBWSG to affect ALL cause mortality.
# Out:
#   location     sex  age_start   age_end  year_start  year_end affected_entity  \
# 0    India  Female        0.0  0.019178        1990      1991             all
# 1    India  Female        0.0  0.019178        1990      1991             all
# 2    India  Female        0.0  0.019178        1990      1991             all
# 3    India  Female        0.0  0.019178        1990      1991             all
# 4    India  Female        0.0  0.019178        1990      1991             all
#
#         affected_measure parameter
# 0  excess_mortality_rate     cat10
# 1  excess_mortality_rate    cat106
# 2  excess_mortality_rate     cat11
# 3  excess_mortality_rate    cat116
# 4  excess_mortality_rate    cat117

# %%
index.affected_measure.nunique()
# Out:
# 1

# %%
index.affected_measure.value_counts()
# Out:
# excess_mortality_rate    73416
# Name: affected_measure, dtype: int64

# %%
index.affected_entity.value_counts()
# Out:
# all    73416
# Name: affected_entity, dtype: int64

# %%
df = store.get('/risk_factor/low_birth_weight_and_short_gestation/relative_risk/draw_0')
df.head()
# Out:
# 0    968.702386
# 1    171.751901
# 2    513.870580
# 3    182.396469
# 4     61.431240
# Name: draw_0, dtype: float64

# %%
#merge index table and relative risk table to match the relative risk with the approrpiate rows
#Each row specifies the RR for that lbssg category and the relative risk for the affected measure.

merged = index.merge(df, right_index=True, left_index=True)
merged.head()
# Out:
#   location     sex  age_start   age_end  year_start  year_end affected_entity  \
# 0    India  Female        0.0  0.019178        1990      1991             all
# 1    India  Female        0.0  0.019178        1990      1991             all
# 2    India  Female        0.0  0.019178        1990      1991             all
# 3    India  Female        0.0  0.019178        1990      1991             all
# 4    India  Female        0.0  0.019178        1990      1991             all
#
#         affected_measure parameter      draw_0
# 0  excess_mortality_rate     cat10  968.702386
# 1  excess_mortality_rate    cat106  171.751901
# 2  excess_mortality_rate     cat11  513.870580
# 3  excess_mortality_rate    cat116  182.396469
# 4  excess_mortality_rate    cat117   61.431240

# %%
np.unique(merged['affected_measure'])
# Out:
# array(['excess_mortality_rate'], dtype=object)

# %%
nn = merged.where(merged['affected_entity'].str.contains('neonatal')).dropna()
nn = nn.where(nn['year_start'] == 2017).dropna()

# create a number for categories of exposure so that it can be easily plotted for comparison 
    # across subtypes

cats = ['cat10', 'cat106', 'cat11', 'cat116', 'cat117', 'cat123', 'cat14',
       'cat15', 'cat17', 'cat19', 'cat2', 'cat20', 'cat21', 'cat22',
       'cat23', 'cat24', 'cat25', 'cat26', 'cat27', 'cat28', 'cat29',
       'cat30', 'cat31', 'cat32', 'cat33', 'cat34', 'cat35', 'cat36',
       'cat37', 'cat38', 'cat39', 'cat40', 'cat41', 'cat42', 'cat43',
       'cat44', 'cat45', 'cat46', 'cat47', 'cat48', 'cat49', 'cat50',
       'cat51', 'cat52', 'cat53', 'cat54', 'cat55', 'cat56', 'cat8',
       'cat80', 'cat81', 'cat82', 'cat88', 'cat89', 'cat90', 'cat95',
       'cat96']
nums = list(range(0,57))
cat_nums = pd.DataFrame()
cat_nums['parameter'] = cats
cat_nums['num'] = nums

nn = nn.merge(cat_nums, right_on='parameter', left_on='parameter')
nn.head()
# Out:
# Empty DataFrame
# Columns: [location, sex, age_start, age_end, year_start, year_end, affected_entity, affected_measure, draw_0, parameter, num]
# Index: []

# %%
np.unique(nn['affected_entity'])
# Out:
# array([], dtype=object)

# %%
early_nn_female = nn.where(nn['sex'] == 'Female').where(nn['age_start'] == 0).dropna()
early_nn_male = nn.where(nn['sex'] == 'Male').where(nn['age_start'] == 0).dropna()
late_nn_female = nn.where(nn['sex'] == 'Female').where(nn['age_start'] == 1.917808e-02).dropna()
late_nn_male = nn.where(nn['sex'] == 'Male').where(nn['age_start'] == 1.917808e-02).dropna()
post_nn_female = nn.where(nn['sex'] == 'Female').where(nn['age_start'] == 7.671233e-02).dropna()
post_nn_male = nn.where(nn['sex'] == 'Male').where(nn['age_start'] == 7.671233e-02).dropna()

# %%
early_nn_female.where(early_nn_female['affected_entity'] == 'other_neonatal_disorders').dropna()
# Out:
# Empty DataFrame
# Columns: [location, sex, age_start, age_end, year_start, year_end, affected_entity, affected_measure, draw_0, parameter, num]
# Index: []

# %%
plt.plot(early_nn_female['num'].where(early_nn_female['affected_entity'] == 'other_neonatal_disorders').dropna(),early_nn_female['draw_0'].where(early_nn_female['affected_entity'] == 'other_neonatal_disorders').dropna())
plt.plot(early_nn_female['num'].where(early_nn_female['affected_entity'] == 'hemolytic_disease_and_other_neonatal_jaundice').dropna(),early_nn_female['draw_0'].where(early_nn_female['affected_entity'] == 'hemolytic_disease_and_other_neonatal_jaundice').dropna())
plt.plot(early_nn_female['num'].where(early_nn_female['affected_entity'] == 'neonatal_encephalopathy_due_to_birth_asphyxia_and_trauma').dropna(),early_nn_female['draw_0'].where(early_nn_female['affected_entity'] == 'neonatal_encephalopathy_due_to_birth_asphyxia_and_trauma').dropna())
plt.plot(early_nn_female['num'].where(early_nn_female['affected_entity'] == 'neonatal_preterm_birth').dropna(),early_nn_female['draw_0'].where(early_nn_female['affected_entity'] == 'neonatal_preterm_birth').dropna())
plt.plot(early_nn_female['num'].where(early_nn_female['affected_entity'] == 'neonatal_sepsis_and_other_neonatal_infections').dropna(),early_nn_female['draw_0'].where(early_nn_female['affected_entity'] == 'neonatal_sepsis_and_other_neonatal_infections').dropna())
plt.legend(['other_neonatal_disorders',
           'hemolytic_disease_and_other_neonatal_jaundice',
           'neonatal_encephalopathy_due_to_birth_asphyxia_and_trauma',
           'neonatal_preterm_birth',
           'neonatal_sepsis_and_other_neonatal_infections'])

# %%
plt.plot(early_nn_male['num'].where(early_nn_male['affected_entity'] == 'other_neonatal_disorders').dropna(),early_nn_male['draw_0'].where(early_nn_male['affected_entity'] == 'other_neonatal_disorders').dropna())
plt.plot(early_nn_male['num'].where(early_nn_male['affected_entity'] == 'hemolytic_disease_and_other_neonatal_jaundice').dropna(),early_nn_male['draw_0'].where(early_nn_male['affected_entity'] == 'hemolytic_disease_and_other_neonatal_jaundice').dropna())
plt.plot(early_nn_male['num'].where(early_nn_male['affected_entity'] == 'neonatal_encephalopathy_due_to_birth_asphyxia_and_trauma').dropna(),early_nn_male['draw_0'].where(early_nn_male['affected_entity'] == 'neonatal_encephalopathy_due_to_birth_asphyxia_and_trauma').dropna())
plt.plot(early_nn_male['num'].where(early_nn_male['affected_entity'] == 'neonatal_preterm_birth').dropna(),early_nn_male['draw_0'].where(early_nn_male['affected_entity'] == 'neonatal_preterm_birth').dropna())
plt.plot(early_nn_male['num'].where(early_nn_male['affected_entity'] == 'neonatal_sepsis_and_other_neonatal_infections').dropna(),early_nn_male['draw_0'].where(early_nn_male['affected_entity'] == 'neonatal_sepsis_and_other_neonatal_infections').dropna())
plt.legend(['other_neonatal_disorders',
           'hemolytic_disease_and_other_neonatal_jaundice',
           'neonatal_encephalopathy_due_to_birth_asphyxia_and_trauma',
           'neonatal_preterm_birth',
           'neonatal_sepsis_and_other_neonatal_infections'])

# %%
plt.plot(late_nn_female['num'].where(late_nn_female['affected_entity'] == 'other_neonatal_disorders').dropna(),late_nn_female['draw_0'].where(late_nn_female['affected_entity'] == 'other_neonatal_disorders').dropna())
plt.plot(late_nn_female['num'].where(late_nn_female['affected_entity'] == 'hemolytic_disease_and_other_neonatal_jaundice').dropna(),late_nn_female['draw_0'].where(late_nn_female['affected_entity'] == 'hemolytic_disease_and_other_neonatal_jaundice').dropna())
plt.plot(late_nn_female['num'].where(late_nn_female['affected_entity'] == 'neonatal_encephalopathy_due_to_birth_asphyxia_and_trauma').dropna(),late_nn_female['draw_0'].where(late_nn_female['affected_entity'] == 'neonatal_encephalopathy_due_to_birth_asphyxia_and_trauma').dropna())
plt.plot(late_nn_female['num'].where(late_nn_female['affected_entity'] == 'neonatal_preterm_birth').dropna(),late_nn_female['draw_0'].where(late_nn_female['affected_entity'] == 'neonatal_preterm_birth').dropna())
plt.plot(late_nn_female['num'].where(late_nn_female['affected_entity'] == 'neonatal_sepsis_and_other_neonatal_infections').dropna(),late_nn_female['draw_0'].where(late_nn_female['affected_entity'] == 'neonatal_sepsis_and_other_neonatal_infections').dropna())
plt.legend(['other_neonatal_disorders',
           'hemolytic_disease_and_other_neonatal_jaundice',
           'neonatal_encephalopathy_due_to_birth_asphyxia_and_trauma',
           'neonatal_preterm_birth',
           'neonatal_sepsis_and_other_neonatal_infections'])

# %%
plt.plot(late_nn_male['num'].where(late_nn_male['affected_entity'] == 'other_neonatal_disorders').dropna(),late_nn_male['draw_0'].where(late_nn_male['affected_entity'] == 'other_neonatal_disorders').dropna())
plt.plot(late_nn_male['num'].where(late_nn_male['affected_entity'] == 'hemolytic_disease_and_other_neonatal_jaundice').dropna(),late_nn_male['draw_0'].where(late_nn_male['affected_entity'] == 'hemolytic_disease_and_other_neonatal_jaundice').dropna())
plt.plot(late_nn_male['num'].where(late_nn_male['affected_entity'] == 'neonatal_encephalopathy_due_to_birth_asphyxia_and_trauma').dropna(),late_nn_male['draw_0'].where(late_nn_male['affected_entity'] == 'neonatal_encephalopathy_due_to_birth_asphyxia_and_trauma').dropna())
plt.plot(late_nn_male['num'].where(late_nn_male['affected_entity'] == 'neonatal_preterm_birth').dropna(),late_nn_male['draw_0'].where(late_nn_male['affected_entity'] == 'neonatal_preterm_birth').dropna())
plt.plot(late_nn_male['num'].where(late_nn_male['affected_entity'] == 'neonatal_sepsis_and_other_neonatal_infections').dropna(),late_nn_male['draw_0'].where(late_nn_male['affected_entity'] == 'neonatal_sepsis_and_other_neonatal_infections').dropna())
plt.legend(['other_neonatal_disorders',
           'hemolytic_disease_and_other_neonatal_jaundice',
           'neonatal_encephalopathy_due_to_birth_asphyxia_and_trauma',
           'neonatal_preterm_birth',
           'neonatal_sepsis_and_other_neonatal_infections'])

# %%
plt.plot(post_nn_female['num'].where(post_nn_female['affected_entity'] == 'other_neonatal_disorders').dropna(),post_nn_female['draw_0'].where(post_nn_female['affected_entity'] == 'other_neonatal_disorders').dropna())
plt.plot(post_nn_female['num'].where(post_nn_female['affected_entity'] == 'hemolytic_disease_and_other_neonatal_jaundice').dropna(),post_nn_female['draw_0'].where(post_nn_female['affected_entity'] == 'hemolytic_disease_and_other_neonatal_jaundice').dropna())
plt.plot(post_nn_female['num'].where(post_nn_female['affected_entity'] == 'neonatal_encephalopathy_due_to_birth_asphyxia_and_trauma').dropna(),post_nn_female['draw_0'].where(post_nn_female['affected_entity'] == 'neonatal_encephalopathy_due_to_birth_asphyxia_and_trauma').dropna())
plt.plot(post_nn_female['num'].where(post_nn_female['affected_entity'] == 'neonatal_preterm_birth').dropna(),post_nn_female['draw_0'].where(post_nn_female['affected_entity'] == 'neonatal_preterm_birth').dropna())
plt.plot(post_nn_female['num'].where(post_nn_female['affected_entity'] == 'neonatal_sepsis_and_other_neonatal_infections').dropna(),post_nn_female['draw_0'].where(post_nn_female['affected_entity'] == 'neonatal_sepsis_and_other_neonatal_infections').dropna())
plt.legend(['other_neonatal_disorders',
           'hemolytic_disease_and_other_neonatal_jaundice',
           'neonatal_encephalopathy_due_to_birth_asphyxia_and_trauma',
           'neonatal_preterm_birth',
           'neonatal_sepsis_and_other_neonatal_infections'])

# %%
plt.plot(post_nn_male['num'].where(post_nn_male['affected_entity'] == 'other_neonatal_disorders').dropna(),post_nn_male['draw_0'].where(post_nn_male['affected_entity'] == 'other_neonatal_disorders').dropna())
plt.plot(post_nn_male['num'].where(post_nn_male['affected_entity'] == 'hemolytic_disease_and_other_neonatal_jaundice').dropna(),post_nn_male['draw_0'].where(post_nn_male['affected_entity'] == 'hemolytic_disease_and_other_neonatal_jaundice').dropna())
plt.plot(post_nn_male['num'].where(post_nn_male['affected_entity'] == 'neonatal_encephalopathy_due_to_birth_asphyxia_and_trauma').dropna(),post_nn_male['draw_0'].where(post_nn_male['affected_entity'] == 'neonatal_encephalopathy_due_to_birth_asphyxia_and_trauma').dropna())
plt.plot(post_nn_male['num'].where(post_nn_male['affected_entity'] == 'neonatal_preterm_birth').dropna(),post_nn_male['draw_0'].where(post_nn_male['affected_entity'] == 'neonatal_preterm_birth').dropna())
plt.plot(post_nn_male['num'].where(post_nn_male['affected_entity'] == 'neonatal_sepsis_and_other_neonatal_infections').dropna(),post_nn_male['draw_0'].where(post_nn_male['affected_entity'] == 'neonatal_sepsis_and_other_neonatal_infections').dropna())
plt.legend(['other_neonatal_disorders',
           'hemolytic_disease_and_other_neonatal_jaundice',
           'neonatal_encephalopathy_due_to_birth_asphyxia_and_trauma',
           'neonatal_preterm_birth',
           'neonatal_sepsis_and_other_neonatal_infections'])

# %%
menin = merged.where(merged['affected_entity'].str.contains('eningitis')).dropna()
menin = menin.where(merged['year_start'] == 2017).dropna()
menin.head()
# Out:
# Empty DataFrame
# Columns: [location, sex, age_start, age_end, year_start, year_end, affected_entity, affected_measure, parameter, draw_0]
# Index: []

# %%
early_neonatal_female = menin.where(menin['age_start'] == 0).where(menin['sex'] == 'Female').dropna()
early_neonatal_male = menin.where(menin['age_start'] == 0).where(menin['sex'] == 'Male').dropna()
late_neonatal_female = menin.where(menin['age_start'] == 1.917808e-02).where(menin['sex'] == 'Female').dropna()
late_neonatal_male = menin.where(menin['age_start'] == 1.917808e-02).where(menin['sex'] == 'Male').dropna()
post_neonatal_female = menin.where(menin['age_start'] == 7.671233e-02).where(menin['sex'] == 'Female').dropna()
post_neonatal_male = menin.where(menin['age_start'] == 7.671233e-02).where(menin['sex'] == 'Male').dropna()

# %%
# create a number for categories of exposure so that it can be easily plotted for comparison 
    # across subtypes

cats = ['cat10', 'cat106', 'cat11', 'cat116', 'cat117', 'cat123', 'cat14',
       'cat15', 'cat17', 'cat19', 'cat2', 'cat20', 'cat21', 'cat22',
       'cat23', 'cat24', 'cat25', 'cat26', 'cat27', 'cat28', 'cat29',
       'cat30', 'cat31', 'cat32', 'cat33', 'cat34', 'cat35', 'cat36',
       'cat37', 'cat38', 'cat39', 'cat40', 'cat41', 'cat42', 'cat43',
       'cat44', 'cat45', 'cat46', 'cat47', 'cat48', 'cat49', 'cat50',
       'cat51', 'cat52', 'cat53', 'cat54', 'cat55', 'cat56', 'cat8',
       'cat80', 'cat81', 'cat82', 'cat88', 'cat89', 'cat90', 'cat95',
       'cat96']
nums = list(range(0,57))
cat_nums = pd.DataFrame()
cat_nums['parameter'] = cats
cat_nums['num'] = nums

early_neonatal_female = early_neonatal_female.merge(cat_nums, right_on='parameter', left_on='parameter')
early_neonatal_male = early_neonatal_male.merge(cat_nums, right_on='parameter', left_on='parameter')
late_neonatal_female = late_neonatal_female.merge(cat_nums, right_on='parameter', left_on='parameter')
late_neonatal_male = late_neonatal_male.merge(cat_nums, right_on='parameter', left_on='parameter')
post_neonatal_female = post_neonatal_female.merge(cat_nums, right_on='parameter', left_on='parameter')
post_neonatal_male = post_neonatal_male.merge(cat_nums, right_on='parameter', left_on='parameter')

# %%
plt.plot(early_neonatal_female['num'].where(early_neonatal_female['affected_entity'] == 'h_influenzae_type_b_meningitis').dropna(),
        early_neonatal_female['draw_0'].where(early_neonatal_female['affected_entity'] == 'h_influenzae_type_b_meningitis').dropna())

plt.plot(early_neonatal_female['num'].where(early_neonatal_female['affected_entity'] == 'meningococcal_meningitis').dropna(),
        early_neonatal_female['draw_0'].where(early_neonatal_female['affected_entity'] == 'meningococcal_meningitis').dropna())

plt.plot(early_neonatal_female['num'].where(early_neonatal_female['affected_entity'] == 'other_meningitis').dropna(),
        early_neonatal_female['draw_0'].where(early_neonatal_female['affected_entity'] == 'other_meningitis').dropna())

plt.plot(early_neonatal_female['num'].where(early_neonatal_female['affected_entity'] == 'pneumococcal_meningitis').dropna(),
        early_neonatal_female['draw_0'].where(early_neonatal_female['affected_entity'] == 'pneumococcal_meningitis').dropna())

plt.legend(['h_influenzae_type_b_meningitis','meningococcal_meningitis',
           'other_meningitis','pneumococcal_meningitis'])
plt.title('LBWSG RRs for early neonatal females by subtype of meningitis')
# Out:
# Text(0.5, 1.0, 'LBWSG RRs for early neonatal females by subtype of meningitis')

# %%
plt.plot(early_neonatal_male['num'].where(early_neonatal_male['affected_entity'] == 'h_influenzae_type_b_meningitis').dropna(),
        early_neonatal_male['draw_0'].where(early_neonatal_male['affected_entity'] == 'h_influenzae_type_b_meningitis').dropna())

plt.plot(early_neonatal_male['num'].where(early_neonatal_male['affected_entity'] == 'meningococcal_meningitis').dropna(),
        early_neonatal_male['draw_0'].where(early_neonatal_male['affected_entity'] == 'meningococcal_meningitis').dropna())

plt.plot(early_neonatal_male['num'].where(early_neonatal_male['affected_entity'] == 'other_meningitis').dropna(),
        early_neonatal_male['draw_0'].where(early_neonatal_male['affected_entity'] == 'other_meningitis').dropna())

plt.plot(early_neonatal_male['num'].where(early_neonatal_male['affected_entity'] == 'pneumococcal_meningitis').dropna(),
        early_neonatal_male['draw_0'].where(early_neonatal_male['affected_entity'] == 'pneumococcal_meningitis').dropna())

plt.legend(['h_influenzae_type_b_meningitis','meningococcal_meningitis',
           'other_meningitis','pneumococcal_meningitis'])
plt.title('LBWSG RRs for early neonatal males by subtype of meningitis')
# Out:
# Text(0.5, 1.0, 'LBWSG RRs for early neonatal males by subtype of meningitis')

# %%
plt.plot(late_neonatal_female['num'].where(late_neonatal_female['affected_entity'] == 'h_influenzae_type_b_meningitis').dropna(),
        late_neonatal_female['draw_0'].where(late_neonatal_female['affected_entity'] == 'h_influenzae_type_b_meningitis').dropna())

plt.plot(late_neonatal_female['num'].where(late_neonatal_female['affected_entity'] == 'meningococcal_meningitis').dropna(),
        late_neonatal_female['draw_0'].where(late_neonatal_female['affected_entity'] == 'meningococcal_meningitis').dropna())

plt.plot(late_neonatal_female['num'].where(late_neonatal_female['affected_entity'] == 'other_meningitis').dropna(),
        late_neonatal_female['draw_0'].where(late_neonatal_female['affected_entity'] == 'other_meningitis').dropna())

plt.plot(late_neonatal_female['num'].where(late_neonatal_female['affected_entity'] == 'pneumococcal_meningitis').dropna(),
        late_neonatal_female['draw_0'].where(late_neonatal_female['affected_entity'] == 'pneumococcal_meningitis').dropna())

plt.legend(['h_influenzae_type_b_meningitis','meningococcal_meningitis',
           'other_meningitis','pneumococcal_meningitis'])
plt.title('LBWSG RRs for late neonatal females by subtype of meningitis')
# Out:
# Text(0.5, 1.0, 'LBWSG RRs for late neonatal females by subtype of meningitis')

# %%
plt.plot(late_neonatal_male['num'].where(late_neonatal_male['affected_entity'] == 'h_influenzae_type_b_meningitis').dropna(),
        late_neonatal_male['draw_0'].where(late_neonatal_male['affected_entity'] == 'h_influenzae_type_b_meningitis').dropna())

plt.plot(late_neonatal_male['num'].where(late_neonatal_male['affected_entity'] == 'meningococcal_meningitis').dropna(),
        late_neonatal_male['draw_0'].where(late_neonatal_male['affected_entity'] == 'meningococcal_meningitis').dropna())

plt.plot(late_neonatal_male['num'].where(late_neonatal_male['affected_entity'] == 'other_meningitis').dropna(),
        late_neonatal_male['draw_0'].where(late_neonatal_male['affected_entity'] == 'other_meningitis').dropna())

plt.plot(late_neonatal_male['num'].where(late_neonatal_male['affected_entity'] == 'pneumococcal_meningitis').dropna(),
        late_neonatal_male['draw_0'].where(late_neonatal_male['affected_entity'] == 'pneumococcal_meningitis').dropna())

plt.legend(['h_influenzae_type_b_meningitis','meningococcal_meningitis',
           'other_meningitis','pneumococcal_meningitis'])
plt.title('LBWSG RRs for late neonatal males by subtype of meningitis')
# Out:
# Text(0.5, 1.0, 'LBWSG RRs for late neonatal males by subtype of meningitis')

# %%
plt.plot(post_neonatal_female['num'].where(post_neonatal_female['affected_entity'] == 'h_influenzae_type_b_meningitis').dropna(),
        post_neonatal_female['draw_0'].where(post_neonatal_female['affected_entity'] == 'h_influenzae_type_b_meningitis').dropna())

plt.plot(post_neonatal_female['num'].where(post_neonatal_female['affected_entity'] == 'meningococcal_meningitis').dropna(),
        post_neonatal_female['draw_0'].where(post_neonatal_female['affected_entity'] == 'meningococcal_meningitis').dropna())

plt.plot(post_neonatal_female['num'].where(post_neonatal_female['affected_entity'] == 'other_meningitis').dropna(),
        post_neonatal_female['draw_0'].where(post_neonatal_female['affected_entity'] == 'other_meningitis').dropna())

plt.plot(post_neonatal_female['num'].where(post_neonatal_female['affected_entity'] == 'pneumococcal_meningitis').dropna(),
        post_neonatal_female['draw_0'].where(post_neonatal_female['affected_entity'] == 'pneumococcal_meningitis').dropna())

plt.legend(['h_influenzae_type_b_meningitis','meningococcal_meningitis',
           'other_meningitis','pneumococcal_meningitis'])
plt.title('LBWSG RRs for post neonatal females by subtype of meningitis')
# Out:
# Text(0.5, 1.0, 'LBWSG RRs for post neonatal females by subtype of meningitis')

# %%
plt.plot(post_neonatal_male['num'].where(post_neonatal_male['affected_entity'] == 'h_influenzae_type_b_meningitis').dropna(),
        post_neonatal_male['draw_0'].where(post_neonatal_male['affected_entity'] == 'h_influenzae_type_b_meningitis').dropna())

plt.plot(post_neonatal_male['num'].where(post_neonatal_male['affected_entity'] == 'meningococcal_meningitis').dropna(),
        post_neonatal_male['draw_0'].where(post_neonatal_male['affected_entity'] == 'meningococcal_meningitis').dropna())

plt.plot(post_neonatal_male['num'].where(post_neonatal_male['affected_entity'] == 'other_meningitis').dropna(),
        post_neonatal_male['draw_0'].where(post_neonatal_male['affected_entity'] == 'other_meningitis').dropna())

plt.plot(post_neonatal_male['num'].where(post_neonatal_male['affected_entity'] == 'pneumococcal_meningitis').dropna(),
        post_neonatal_male['draw_0'].where(post_neonatal_male['affected_entity'] == 'pneumococcal_meningitis').dropna())

plt.legend(['h_influenzae_type_b_meningitis','meningococcal_meningitis',
           'other_meningitis','pneumococcal_meningitis'])
plt.title('LBWSG RRs for post neonatal males by subtype of meningitis')
# Out:
# Text(0.5, 1.0, 'LBWSG RRs for post neonatal males by subtype of meningitis')
