# %%
# !pwd
# !ls
# Out:
# /ihme/homes/nicoly/notebooks/Project BEP_gates

# %%
from vivarium import Artifact
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from db_queries import get_ids, get_outputs
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-23d6dbf28ecc> in <module>
#       2 import pandas as pd
#       3 import numpy as np
# ----> 4 import seaborn as sns
#       5 import matplotlib.pyplot as plt
#       6 from db_queries import get_ids, get_outputs
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
output_dirs = ['/share/costeffectiveness/results/vivarium_gates_bep/malnutrition/india/2020_02_05_03_02_13/count_space/',
               '/share/costeffectiveness/results/vivarium_gates_bep/malnutrition/mali/2020_02_05_03_02_02/count_space/',
               '/share/costeffectiveness/results/vivarium_gates_bep/malnutrition/tanzania/2020_02_05_03_07_37/count_space/']
locations = ['India',
             'Mali',
            'Tanzania']

# %%
def get_aggregate_results(measure):
    data = measure.drop(columns='input_draw')
    data_mean = data.groupby(['malnourishment_category','age_group']).mean()
    data_min = data.groupby(['malnourishment_category','age_group']).min()
    data_max = data.groupby(['malnourishment_category','age_group']).max()
    data_fin1 = data_mean.merge(data_min, right_index=True, left_index=True, suffixes=['_mean','_lower'])
    data_fin2 = data_mean.merge(data_max, right_index=True, left_index=True, suffixes=['_mean','_upper'])
    data_fin = data_fin1.merge(data_fin2, right_index=True, left_index=True, suffixes=['','_drop'])
    data_fin = data_fin.drop(columns=[c for c in data_fin.columns if 'drop' in c])
    return data_fin

master_results = pd.DataFrame()
for i in list(range(0,3)):
    deaths = pd.read_hdf(output_dirs[i] + 'deaths.hdf').reset_index().groupby(['malnourishment_category',
                               'age_group','input_draw']).sum().reset_index()
    person_time = pd.read_hdf(output_dirs[i] + 'person_time.hdf').reset_index().groupby(['malnourishment_category',
                               'age_group','input_draw']).sum().reset_index()
    ylds = pd.read_hdf(output_dirs[i] + 'ylds.hdf').reset_index().groupby(['malnourishment_category',
                               'age_group','input_draw']).sum().reset_index()
    ylls = pd.read_hdf(output_dirs[i] + 'ylls.hdf').reset_index().groupby(['malnourishment_category',
                               'age_group','input_draw']).sum().reset_index()
    
    deaths = deaths.merge(person_time, right_on=['input_draw','malnourishment_category','age_group'],
                         left_on=['input_draw','malnourishment_category','age_group'])
    deaths['death_rate'] = deaths['deaths'] / deaths['person_time']    
   
    dalys = ylds.merge(ylls, right_on=['input_draw','age_group','malnourishment_category'],
                            left_on=['input_draw','age_group','malnourishment_category'])
    dalys = dalys.merge(person_time, right_on=['input_draw','age_group','malnourishment_category'],
                            left_on=['input_draw','age_group','malnourishment_category'], suffixes=['','_drop'])
    dalys['yld_rate'] = dalys['ylds'] / dalys['person_time']
    dalys['yll_rate'] = dalys['ylls'] / dalys['person_time']
    dalys['dalys'] = dalys['ylds'] + dalys['ylls']
    dalys['daly_rate'] = dalys['yld_rate'] + dalys['yll_rate']
    
    deaths_fin = get_aggregate_results(deaths)
    dalys_fin = get_aggregate_results(dalys)
    results = deaths_fin.merge(dalys_fin, right_index=True, left_index=True, suffixes=['','_drop'])
    results['location'] = locations[i]
    master_results = master_results.append(results)
master_results = master_results.reset_index().set_index(['location','malnourishment_category','age_group'])
master_results = master_results.drop(columns=[c for c in master_results.columns if '_drop' in c])
master_results_rates = master_results.drop(columns = [c for c in master_results if 'rate' not in c])
master_results_rates = master_results_rates * 100_000
master_results_rates
# Out:
#                                                  death_rate_mean  \
# location malnourishment_category age_group
# India    malnourished            1_to_4               202.104271
#                                  1mo_to_6mo          1936.526046
#                                  6mo_to_1            1983.155237
#                                  early_neonatal    113097.216042
#                                  late_neonatal       7530.095941
#          not_malnourished        1_to_4               127.143918
#                                  1mo_to_6mo          1044.106500
#                                  6mo_to_1            1063.130361
#                                  early_neonatal     55050.260216
#                                  late_neonatal       4624.358423
# Mali     malnourished            1_to_4              1875.840159
#                                  1mo_to_6mo          4539.541865
#                                  6mo_to_1            4952.686156
#                                  early_neonatal    143341.662858
#                                  late_neonatal      10476.871139
#          not_malnourished        1_to_4              1339.276969
#                                  1mo_to_6mo          3256.430516
#                                  6mo_to_1            3277.515335
#                                  early_neonatal     86912.528323
#                                  late_neonatal       8062.370634
# Tanzania malnourished            1_to_4               647.300501
#                                  1mo_to_6mo          2919.073632
#                                  6mo_to_1            3042.053968
#                                  early_neonatal     73361.082981
#                                  late_neonatal       5641.060488
#          not_malnourished        1_to_4               451.704040
#                                  1mo_to_6mo          2079.992180
#                                  6mo_to_1            2099.721762
#                                  early_neonatal     61676.691982
#                                  late_neonatal       4842.389047
#
#                                                  death_rate_lower  \
# location malnourishment_category age_group
# India    malnourished            1_to_4                137.515966
#                                  1mo_to_6mo           1560.841907
#                                  6mo_to_1             1392.433231
#                                  early_neonatal      74320.610533
#                                  late_neonatal        6468.231950
#          not_malnourished        1_to_4                114.888576
#                                  1mo_to_6mo            970.344675
#                                  6mo_to_1             1008.648175
#                                  early_neonatal      47636.519509
#                                  late_neonatal        4058.100411
# Mali     malnourished            1_to_4               1405.868550
#                                  1mo_to_6mo           3967.550037
#                                  6mo_to_1             3937.651696
#                                  early_neonatal     110304.088134
#                                  late_neonatal        8307.037118
#          not_malnourished        1_to_4               1044.092115
#                                  1mo_to_6mo           2528.535416
#                                  6mo_to_1             2497.675157
#                                  early_neonatal      68381.009473
#                                  late_neonatal        7100.374211
# Tanzania malnourished            1_to_4                503.029616
#                                  1mo_to_6mo           2435.512521
#                                  6mo_to_1             1968.079311
#                                  early_neonatal      58950.494454
#                                  late_neonatal        4064.137548
#          not_malnourished        1_to_4                370.257161
#                                  1mo_to_6mo           1847.918125
#                                  6mo_to_1             1804.380242
#                                  early_neonatal      51179.135141
#                                  late_neonatal        4128.691017
#
#                                                  death_rate_upper  \
# location malnourishment_category age_group
# India    malnourished            1_to_4                280.203961
#                                  1mo_to_6mo           2713.943183
#                                  6mo_to_1             2552.259239
#                                  6mo_to_1           1732.099038
#                                  early_neonatal     1445.184124
#                                  late_neonatal       601.628277
#          not_malnourished        1_to_4              461.102189
#                                  1mo_to_6mo          643.954699
#                                  6mo_to_1            642.865448
#                                  early_neonatal      832.884555
#                                  late_neonatal       578.014254
#
#                                                  yll_rate_upper  \
# location malnourishment_category age_group
# India    malnourished            1_to_4            2.423440e+04
#                                  1mo_to_6mo        2.378459e+05
#                                  6mo_to_1          2.226780e+05
#                                  early_neonatal    1.567077e+07
#                                  late_neonatal     8.176721e+05
#          not_malnourished        1_to_4            1.286771e+04
#                                  1mo_to_6mo        1.004740e+05
#                                  6mo_to_1          9.876815e+04
#                                  early_neonatal    5.451147e+06
#                                  late_neonatal     4.523416e+05
# Mali     malnourished            1_to_4            2.287143e+05
#                                  1mo_to_6mo        5.573135e+05
#                                  6mo_to_1          4.894047e+05
#                                  early_neonatal    1.788665e+07
#                                  late_neonatal     1.239283e+06
#          not_malnourished        1_to_4            1.282361e+05
#                                  1mo_to_6mo        3.252055e+05
#                                  6mo_to_1          3.217466e+05
#                                  early_neonatal    8.654345e+06
#                                  late_neonatal     8.045181e+05
# Tanzania malnourished            1_to_4            7.628810e+04
#                                  1mo_to_6mo        3.701697e+05
#                                  6mo_to_1          3.265762e+05
#                                  early_neonatal    8.235866e+06
#                                  late_neonatal     6.542579e+05
#          not_malnourished        1_to_4            4.402450e+04
#                                  1mo_to_6mo        2.056831e+05
#                                  6mo_to_1          2.088354e+05
#                                  early_neonatal    6.490854e+06
#                                  late_neonatal     5.482193e+05
#
#                                                  daly_rate_upper
# location malnourishment_category age_group
# India    malnourished            1_to_4             2.670066e+04
#                                  1mo_to_6mo         2.409000e+05
#                                  6mo_to_1           2.257035e+05
#                                  early_neonatal     1.567467e+07
#                                  late_neonatal      8.219820e+05
#          not_malnourished        1_to_4             1.347503e+04
#                                  1mo_to_6mo         1.011248e+05
#                                  6mo_to_1           9.944247e+04
#                                  early_neonatal     5.452446e+06
#                                  late_neonatal      4.539471e+05
# Mali     malnourished            1_to_4             2.310812e+05
#                                  1mo_to_6mo         5.596481e+05
#                                  6mo_to_1           4.916834e+05
#                                  early_neonatal     1.788965e+07
#                                  late_neonatal      1.241261e+06
#          not_malnourished        1_to_4             1.287995e+05
#                                  1mo_to_6mo         3.257338e+05
#                                  6mo_to_1           3.222591e+05
#                                  early_neonatal     8.655236e+06
#                                  late_neonatal      8.054410e+05
# Tanzania malnourished            1_to_4             7.731701e+04
#                                  1mo_to_6mo         3.717564e+05
#                                  6mo_to_1           3.283083e+05
#                                  early_neonatal     8.236890e+06
#                                  late_neonatal      6.546930e+05
#          not_malnourished        1_to_4             4.428655e+04
#                                  1mo_to_6mo         2.061725e+05
#                                  6mo_to_1           2.093166e+05
#                                  early_neonatal     6.491437e+06
#                                  late_neonatal      5.487138e+05
