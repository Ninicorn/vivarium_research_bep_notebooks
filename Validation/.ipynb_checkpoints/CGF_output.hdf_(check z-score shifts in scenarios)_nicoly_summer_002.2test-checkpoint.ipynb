# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>")) #makes the display bars longer and spread out 100% across the screen width
# Out:
# <style>.container { width:100% !important; }</style>

# %%
from vivarium import Artifact
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from db_queries import get_ids, get_outputs
import scipy.stats

# %%
#find file paths
# %cd /share/costeffectiveness/results/vivarium_gates_bep/summer_002.2test/india/2020_10_11_16_39_49/count_data/ 
# %ls

# !whoami
# !date
# Out:
# /ihme/costeffectiveness/results/vivarium_gates_bep/summer_002.2test/india/2020_10_11_16_39_49/count_data
# birth_weight.csv    deaths.csv           population.csv         ylds.csv
# birth_weight.hdf    deaths.hdf           population.hdf         ylds.hdf
# cgf_categories.csv  gestational_age.csv  state_person_time.csv  ylls.csv
# cgf_categories.hdf  gestational_age.hdf  state_person_time.hdf  ylls.hdf
# cgf_z_scores.csv    person_time.csv      transition_count.csv
# cgf_z_scores.hdf    person_time.hdf      transition_count.hdf
# nicoly
# Tue Oct 13 23:23:43 PDT 2020

# %%
#scenarios in each of the runs

#run1 (baseline, mmn, bep_hd_universal_i & targeted_i)
#run2 (bep_ce_universal & targeted)
#run3 (bep_ce_universal & targeted)
#run4 (baseline, mmn, bep_hd_universal_iii & targeted_iii)

#summer model
#scenarios in each of the runs

#run1 (baseline, mmn, bep_hd_universal_i & targeted_i)
#run2 (bep_ce_universal & targeted)
#run3 (bep_ce_universal & targeted)
#run4 (baseline, mmn, bep_hd_universal_iii & targeted_iii)

output_dirs001 = []

output_dirs002 = ['/share/costeffectiveness/results/vivarium_gates_bep/summer_002.2test/india/2020_10_11_16_39_49/count_data/']

output_dirs004 = []

#location labels
locations = ['India','Pakistan','Mali','Tanzania']

#use in sort_values to make custum sort list. I sorted by region. 
sorter = ['India','mali','Mali','Tanzania']
sorterIndex = dict(zip(sorter,range(len(sorter))))

#feb model
output_dirs = ['/share/costeffectiveness/results/vivarium_gates_bep/malnutrition/india/2020_02_05_03_02_13/count_space/',
              '/share/costeffectiveness/results/vivarium_gates_bep/malnutrition/mali/2020_02_05_03_02_02/count_space/',
              '/share/costeffectiveness/results/vivarium_gates_bep/malnutrition/tanzania/2020_02_05_03_07_37/count_space/']



#location labels
locations = ['India','Pakistan','Mali','Tanzania']

#use in sort_values to make custum sort list. I sorted by region. 
sorter = ['India','Pakistan','Mali','Tanzania']
sorterIndex = dict(zip(sorter,range(len(sorter))))

# %% [markdown]
# ## testing

# %%
cgf_india = pd.read_hdf('/share/costeffectiveness/results/vivarium_gates_bep/summer_002.2test/india/2020_10_11_16_39_49/count_data/cgf_z_scores.hdf').reset_index()
print(len(cgf_india))
cgf_india.head()
# Out:
# 6400
#    index      risk treatment_group mother_status measure  input_draw  \
# 0      0  stunting             bep  malnourished    mean           3
# 1      1  stunting             bep  malnourished    mean           3
# 2      2  stunting             bep  malnourished    mean           3
# 3      3  stunting             bep  malnourished    mean           3
# 4      4  stunting             bep  malnourished    mean          21
#
#                    scenario     value           timepoint
# 0           bep_ce_scale_up  9.060500    twenty_nine_days
# 1           bep_ce_scale_up  8.437184  three_six_six_days
# 2  bep_ce_targeted_scale_up  9.060500    twenty_nine_days
# 3  bep_ce_targeted_scale_up  8.437184  three_six_six_days
# 4           bep_ce_scale_up  9.080022    twenty_nine_days

# %%
cgf_india['treatment_group'].value_counts()
# Out:
# none    1600
# bep     1600
# ifa     1600
# mmn     1600
# Name: treatment_group, dtype: int64

# %%
deaths_india = pd.read_hdf('/share/costeffectiveness/results/vivarium_gates_bep/summer_002.2test/india/2020_10_11_16_39_49/count_data/deaths.hdf')
deaths_india.head()
# Out:
#   age_group               cause treatment_group mother_status measure  \
# 0    1_to_4  diarrheal_diseases             bep  malnourished   death
# 1    1_to_4  diarrheal_diseases             bep  malnourished   death
# 2    1_to_4  diarrheal_diseases             bep  malnourished   death
# 3    1_to_4  diarrheal_diseases             bep  malnourished   death
# 4    1_to_4  diarrheal_diseases             bep  malnourished   death
#
#    input_draw                  scenario  value
# 0           3           bep_ce_scale_up    2.0
# 1           3  bep_ce_targeted_scale_up    2.0
# 2          21           bep_ce_scale_up    2.0
# 3          21  bep_ce_targeted_scale_up    2.0
# 4          29           bep_ce_scale_up    4.0

# %%
deaths_india['cause'].value_counts()
# Out:
# protein_energy_malnutrition     4000
# other_causes                    4000
# lower_respiratory_infections    4000
# measles                         4000
# diarrheal_diseases              4000
# Name: cause, dtype: int64

# %%
died_india = deaths_india.groupby(['input_draw', 'scenario','mother_status', 'treatment_group']).sum().reset_index()
died_india = died_india.rename(columns={'value':'deaths'})
died_india.head()
# Out:
#    input_draw         scenario mother_status treatment_group  deaths
# 0           3  bep_ce_scale_up  malnourished             bep   489.0
# 1           3  bep_ce_scale_up  malnourished             ifa     0.0
# 2           3  bep_ce_scale_up  malnourished             mmn     0.0
# 3           3  bep_ce_scale_up  malnourished            none   152.0
# 4           3  bep_ce_scale_up        normal             bep  2266.0

# %% [markdown]
# # CGF z-score shift check

# %% [markdown]
# ## RUN 1 BASELINE

# %%
#RUN 1 (baseline, mmn, bep_hd_scale_up and bep_hd_targeted)
master_cgf_001 = pd.DataFrame()

for i in list(range(len(output_dirs001))):
    #cgf
    cgf_001 = pd.read_hdf(output_dirs001[i] + 'cgf_z_scores.hdf').reset_index().sort_values(by=['risk','measure','scenario','treatment_group','mother_status'])
    cgf_001 = cgf_001.rename(columns={'value':'zscore'})
    cgf_001['z_score'] = cgf_001['zscore'] - 10
    
    #population
    pop = pd.read_hdf(output_dirs001[i] + 'population.hdf').reset_index()
    pop = pop.where(pop['measure'] == 'total_population').dropna().rename(columns={'value':'start_population'}).drop(columns=['index','measure'])
    
    died = pd.read_hdf(output_dirs001[i] + 'deaths.hdf')
    died = died.groupby(['input_draw', 'scenario','mother_status', 'treatment_group']).sum().rename(columns={'value':'deaths'}).reset_index()
    
    pop = pop.merge(died, right_on=['scenario','treatment_group','mother_status','input_draw'], left_on=['scenario','treatment_group','mother_status','input_draw'], how='left')
    
    data = cgf_001.merge(pop, right_on=['scenario','treatment_group','mother_status','input_draw'], left_on=['scenario','treatment_group','mother_status','input_draw'])
    data = data.groupby(['risk','measure','scenario','treatment_group','mother_status']).mean().drop(columns=['input_draw','index']).reset_index() #average over input draws
    
    data['alive'] = data['start_population'] - data['deaths']
    data['alive_x_cgf'] = data['z_score'] * data['alive'] #cannot use this as weight because the population is the population supplemented (or at birth) whereas the z-score is among alive population at 2 years
    data['location'] = locations[i]
    data['scenario'] = data['scenario'].replace('bep_hd_scale_up', 'bep_hd_scale_up_i').replace('bep_hd_targeted_scale_up','bep_hd_targeted_scale_up_i')    
    master_cgf_001 = master_cgf_001.append(data)
    
master_cgf_001.head(10)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#STUNTING

stunting001 = master_cgf_001[master_cgf_001['scenario'].isin(['baseline']) & master_cgf_001['treatment_group'].isin(['ifa','none']) & master_cgf_001['location'].isin(['India'])  & master_cgf_001['risk'].isin(['stunting']) & master_cgf_001['measure'].isin(['mean'])]
stunting001
# Out:
#        risk measure  scenario treatment_group mother_status    zscore  \
# 2  stunting    mean  baseline             ifa  malnourished  9.067246
# 3  stunting    mean  baseline             ifa        normal  9.857427
# 6  stunting    mean  baseline            none  malnourished  9.065966
# 7  stunting    mean  baseline            none        normal  9.856911
#
#     z_score  start_population   deaths     alive  alive_x_cgf location
# 2 -0.932754           5770.46   250.62   5519.84 -5148.654779    India
# 3 -0.142573          28262.46   939.90  27322.56 -3895.451723    India
# 6 -0.934034          11166.04   528.62  10637.42 -9935.707549    India
# 7 -0.143089          54801.04  1888.72  52912.32 -7571.182409    India

# %%
#WASTING

wasting001 = master_cgf_001[master_cgf_001['scenario'].isin(['baseline']) & master_cgf_001['treatment_group'].isin(['ifa','none']) & master_cgf_001['location'].isin(['India'])  & master_cgf_001['risk'].isin(['wasting']) & master_cgf_001['measure'].isin(['mean'])]
wasting001
# Out:
#        risk measure  scenario treatment_group mother_status    zscore  \
# 66  wasting    mean  baseline             ifa  malnourished  9.067246
# 67  wasting    mean  baseline             ifa        normal  9.857427
# 70  wasting    mean  baseline            none  malnourished  9.065966
# 71  wasting    mean  baseline            none        normal  9.856911
#
#      z_score  start_population   deaths     alive  alive_x_cgf location
# 66 -0.932754           5770.46   250.62   5519.84 -5148.654779    India
# 67 -0.142573          28262.46   939.90  27322.56 -3895.451723    India
# 70 -0.934034          11166.04   528.62  10637.42 -9935.707549    India
# 71 -0.143089          54801.04  1888.72  52912.32 -7571.182409    India

# %%
#STUNTING

stunting001 = master_cgf_001[master_cgf_001['scenario'].isin(['bep_hd_scale_up_i']) & master_cgf_001['treatment_group'].isin(['bep','none']) & master_cgf_001['location'].isin(['India'])  & master_cgf_001['risk'].isin(['stunting']) & master_cgf_001['measure'].isin(['mean'])]
stunting001
# Out:
#         risk measure           scenario treatment_group mother_status  \
# 8   stunting    mean  bep_hd_scale_up_i             bep  malnourished
# 9   stunting    mean  bep_hd_scale_up_i             bep        normal
# 14  stunting    mean  bep_hd_scale_up_i            none  malnourished
# 15  stunting    mean  bep_hd_scale_up_i            none        normal
#
#        zscore   z_score  start_population   deaths     alive  alive_x_cgf  \
# 8    9.364885 -0.635115          13444.32   486.36  12957.96 -8229.794822
# 9   10.154668  0.154668          65971.26  1962.38  64008.88  9900.151465
# 14   9.065016 -0.934984           3492.18   165.40   3326.78 -3110.487122
# 15   9.859471 -0.140529          17092.24   588.80  16503.44 -2319.215989
#
#    location
# 8     India
# 9     India
# 14    India
# 15    India

# %%
#WASTING

wastingg001 = master_cgf_001[master_cgf_001['scenario'].isin(['bep_hd_scale_up_i']) & master_cgf_001['treatment_group'].isin(['bep','none']) & master_cgf_001['location'].isin(['India'])  & master_cgf_001['risk'].isin(['wasting']) & master_cgf_001['measure'].isin(['mean'])]
wastingg001
# Out:
#        risk measure           scenario treatment_group mother_status  \
# 72  wasting    mean  bep_hd_scale_up_i             bep  malnourished
# 73  wasting    mean  bep_hd_scale_up_i             bep        normal
# 78  wasting    mean  bep_hd_scale_up_i            none  malnourished
# 79  wasting    mean  bep_hd_scale_up_i            none        normal
#
#        zscore   z_score  start_population   deaths     alive  alive_x_cgf  \
# 72   9.364885 -0.635115          13444.32   486.36  12957.96 -8229.794822
# 73  10.154668  0.154668          65971.26  1962.38  64008.88  9900.151465
# 78   9.065016 -0.934984           3492.18   165.40   3326.78 -3110.487122
# 79   9.859471 -0.140529          17092.24   588.80  16503.44 -2319.215989
#
#    location
# 72    India
# 73    India
# 78    India
# 79    India

# %% [markdown]
# # ------------------------------------------------------------------------------------
# # RUN 2 -scenarios CE universal/targeted (002.2 test)

# %%
#RUN 2 (bep_ce_universal & targeted)

master_cgf_002 = pd.DataFrame()

for i in list(range(len(output_dirs002))):
    #cgf
    cgf_002 = pd.read_hdf(output_dirs002[i] + 'cgf_z_scores.hdf').reset_index().sort_values(by=['input_draw','risk','measure','scenario','treatment_group','mother_status'])
    cgf_002 = cgf_002.rename(columns={'value':'zscore'})
    cgf_002['z_score'] = cgf_002['zscore'] - 10
    
    
    #population
    pop = pd.read_hdf(output_dirs002[i] + 'population.hdf').reset_index()
    pop = pop.where(pop['measure'] == 'total_population').dropna().rename(columns={'value':'start_population'}).drop(columns=['index','measure'])
    
    died = pd.read_hdf(output_dirs002[i] + 'deaths.hdf')
    died = died.groupby(['input_draw', 'scenario','mother_status','treatment_group']).sum().rename(columns={'value':'deaths'}).reset_index()
    
    pop = pop.merge(died, right_on=['scenario','treatment_group','mother_status','input_draw'], left_on=['scenario','treatment_group','mother_status','input_draw'])
    
    data = pd.merge(cgf_002, pop, left_on=['input_draw','scenario','treatment_group','mother_status'], right_on=['input_draw','scenario','treatment_group','mother_status'], how='outer')
    
    data = data.groupby(['risk','measure','scenario','treatment_group','mother_status','timepoint']).mean().drop(columns=['input_draw','index']).reset_index() #average over input draws
    
    data['alive'] = data['start_population'] - data['deaths']
    data['alive_x_cgf'] = data['z_score'] * data['alive'] #cannot use this as weight because the population is the population supplemented (or at birth) whereas the z-score is among alive population at 2 years
    data['location'] = locations[i]
    master_cgf_002 = master_cgf_002.append(data)
    
master_cgf_002.head()
# Out:
#        risk measure         scenario treatment_group mother_status  \
# 0  stunting    mean  bep_ce_scale_up             bep  malnourished
# 1  stunting    mean  bep_ce_scale_up             bep  malnourished
# 2  stunting    mean  bep_ce_scale_up             bep        normal
# 3  stunting    mean  bep_ce_scale_up             bep        normal
# 4  stunting    mean  bep_ce_scale_up             ifa  malnourished
#
#             timepoint    zscore    z_score  start_population   deaths  \
# 0  three_six_six_days  8.433814  -1.566186          13444.32   481.72
# 1    twenty_nine_days  9.084231  -0.915769          13444.32   481.72
# 2  three_six_six_days  8.436119  -1.563881          65971.26  2227.30
# 3    twenty_nine_days  9.086330  -0.913670          65971.26  2227.30
# 4  three_six_six_days  0.000000 -10.000000              0.00     0.00
#
#       alive   alive_x_cgf location
# 0  12962.60 -20301.845819    India
# 1  12962.60 -11870.753471    India
# 2  63743.96 -99687.962683    India
# 3  63743.96 -58240.972309    India
# 4      0.00     -0.000000    India

# %% [markdown]
# ### STUNTING BEP_CE_SCALE_UP UNIVERSAL

# %%
# STUNTING CE_UNIVERSAL 29days

stunting_ce_universal_002 = master_cgf_002[master_cgf_002['risk'].isin(['stunting']) & master_cgf_002['timepoint'].isin(['twenty_nine_days']) & master_cgf_002['scenario'].isin(['bep_ce_scale_up']) & master_cgf_002['treatment_group'].isin(['bep','none']) & master_cgf_002['location'].isin(['India']) & master_cgf_002['measure'].isin(['mean'])]
stunting_ce_universal_002
# Out:
#         risk measure         scenario treatment_group mother_status  \
# 1   stunting    mean  bep_ce_scale_up             bep  malnourished
# 3   stunting    mean  bep_ce_scale_up             bep        normal
# 13  stunting    mean  bep_ce_scale_up            none  malnourished
# 15  stunting    mean  bep_ce_scale_up            none        normal
#
#            timepoint    zscore   z_score  start_population   deaths     alive  \
# 1   twenty_nine_days  9.084231 -0.915769          13444.32   481.72  12962.60
# 3   twenty_nine_days  9.086330 -0.913670          65971.26  2227.30  63743.96
# 13  twenty_nine_days  9.087145 -0.912855           3492.18   152.76   3339.42
# 15  twenty_nine_days  9.084128 -0.915872          17092.24   618.06  16474.18
#
#      alive_x_cgf location
# 1  -11870.753471    India
# 3  -58240.972309    India
# 13  -3048.404897    India
# 15 -15088.244058    India

# %%
# STUNTING CE_UNIVERSAL 366days

stunting_ce_universal_002 = master_cgf_002[master_cgf_002['risk'].isin(['stunting']) & master_cgf_002['timepoint'].isin(['three_six_six_days']) & master_cgf_002['scenario'].isin(['bep_ce_scale_up']) & master_cgf_002['treatment_group'].isin(['bep','none']) & master_cgf_002['location'].isin(['India']) & master_cgf_002['measure'].isin(['mean'])]
stunting_ce_universal_002
# Out:
#         risk measure         scenario treatment_group mother_status  \
# 0   stunting    mean  bep_ce_scale_up             bep  malnourished
# 2   stunting    mean  bep_ce_scale_up             bep        normal
# 12  stunting    mean  bep_ce_scale_up            none  malnourished
# 14  stunting    mean  bep_ce_scale_up            none        normal
#
#              timepoint    zscore   z_score  start_population   deaths  \
# 0   three_six_six_days  8.433814 -1.566186          13444.32   481.72
# 2   three_six_six_days  8.436119 -1.563881          65971.26  2227.30
# 12  three_six_six_days  8.436303 -1.563697           3492.18   152.76
# 14  three_six_six_days  8.434249 -1.565751          17092.24   618.06
#
#        alive   alive_x_cgf location
# 0   12962.60 -20301.845819    India
# 2   63743.96 -99687.962683    India
# 12   3339.42  -5221.841222    India
# 14  16474.18 -25794.468737    India

# %% [markdown]
# ### STUNTING BEP_CE_TARGETED

# %%
# STUNTING CE_TARGETED 29 days

stunting_ce_targeted_002 = master_cgf_002[master_cgf_002['risk'].isin(['stunting']) & master_cgf_002['timepoint'].isin(['twenty_nine_days']) & master_cgf_002['scenario'].isin(['bep_ce_targeted_scale_up']) & master_cgf_002['treatment_group'].isin(['bep','mmn','none']) & master_cgf_002['location'].isin(['India']) &  master_cgf_002['measure'].isin(['mean'])]
stunting_ce_targeted_002
# Out:
#         risk measure                  scenario treatment_group mother_status  \
# 17  stunting    mean  bep_ce_targeted_scale_up             bep  malnourished
# 19  stunting    mean  bep_ce_targeted_scale_up             bep        normal
# 25  stunting    mean  bep_ce_targeted_scale_up             mmn  malnourished
# 27  stunting    mean  bep_ce_targeted_scale_up             mmn        normal
# 29  stunting    mean  bep_ce_targeted_scale_up            none  malnourished
# 31  stunting    mean  bep_ce_targeted_scale_up            none        normal
#
#            timepoint    zscore    z_score  start_population   deaths  \
# 17  twenty_nine_days  9.084231  -0.915769          13444.32   481.72
# 19  twenty_nine_days  0.000000 -10.000000              0.00     0.00
# 25  twenty_nine_days  0.000000 -10.000000              0.00     0.00
# 27  twenty_nine_days  9.086334  -0.913666          65971.26  2249.60
# 29  twenty_nine_days  9.087145  -0.912855           3492.18   152.76
# 31  twenty_nine_days  9.084128  -0.915872          17092.24   618.06
#
#        alive   alive_x_cgf location
# 17  12962.60 -11870.753471    India
# 19      0.00     -0.000000    India
# 25      0.00     -0.000000    India
# 27  63721.66 -58220.307474    India
# 29   3339.42  -3048.404897    India
# 31  16474.18 -15088.244058    India

# %%
# STUNTING CE_TARGETED 366 days

stunting_ce_targeted_002 = master_cgf_002[master_cgf_002['risk'].isin(['stunting']) & master_cgf_002['timepoint'].isin(['three_six_six_days']) & master_cgf_002['scenario'].isin(['bep_ce_targeted_scale_up']) & master_cgf_002['treatment_group'].isin(['bep','mmn','none']) & master_cgf_002['location'].isin(['India']) &  master_cgf_002['measure'].isin(['mean'])]
stunting_ce_targeted_002
# Out:
#         risk measure                  scenario treatment_group mother_status  \
# 16  stunting    mean  bep_ce_targeted_scale_up             bep  malnourished
# 18  stunting    mean  bep_ce_targeted_scale_up             bep        normal
# 24  stunting    mean  bep_ce_targeted_scale_up             mmn  malnourished
# 26  stunting    mean  bep_ce_targeted_scale_up             mmn        normal
# 28  stunting    mean  bep_ce_targeted_scale_up            none  malnourished
# 30  stunting    mean  bep_ce_targeted_scale_up            none        normal
#
#              timepoint    zscore    z_score  start_population   deaths  \
# 16  three_six_six_days  8.433814  -1.566186          13444.32   481.72
# 18  three_six_six_days  0.000000 -10.000000              0.00     0.00
# 24  three_six_six_days  0.000000 -10.000000              0.00     0.00
# 26  three_six_six_days  8.436126  -1.563874          65971.26  2249.60
# 28  three_six_six_days  8.436303  -1.563697           3492.18   152.76
# 30  three_six_six_days  8.434249  -1.565751          17092.24   618.06
#
#        alive   alive_x_cgf location
# 16  12962.60 -20301.845819    India
# 18      0.00     -0.000000    India
# 24      0.00     -0.000000    India
# 26  63721.66 -99652.661936    India
# 28   3339.42  -5221.841222    India
# 30  16474.18 -25794.468737    India

# %% [markdown]
# ### WASTING BEP_CE_UNIVERSAL

# %%
#29 days

wasting_ce_universal_002 = master_cgf_002[master_cgf_002['timepoint'].isin(['twenty_nine_days']) & master_cgf_002['scenario'].isin(['bep_ce_scale_up']) & master_cgf_002['treatment_group'].isin(['bep','none']) & master_cgf_002['location'].isin(['India'])  & master_cgf_002['risk'].isin(['wasting']) & master_cgf_002['measure'].isin(['mean'])]
wasting_ce_universal_002
# Out:
#        risk measure         scenario treatment_group mother_status  \
# 65  wasting    mean  bep_ce_scale_up             bep  malnourished
# 67  wasting    mean  bep_ce_scale_up             bep        normal
# 77  wasting    mean  bep_ce_scale_up            none  malnourished
# 79  wasting    mean  bep_ce_scale_up            none        normal
#
#            timepoint    zscore   z_score  start_population   deaths     alive  \
# 65  twenty_nine_days  9.554054 -0.445946          13444.32   481.72  12962.60
# 67  twenty_nine_days  9.552961 -0.447039          65971.26  2227.30  63743.96
# 77  twenty_nine_days  9.551828 -0.448172           3492.18   152.76   3339.42
# 79  twenty_nine_days  9.555975 -0.444025          17092.24   618.06  16474.18
#
#      alive_x_cgf location
# 65  -5780.616528    India
# 67 -28496.039432    India
# 77  -1496.636133    India
# 79  -7314.939725    India

# %%
#366 days

wasting_ce_universal_002 = master_cgf_002[master_cgf_002['timepoint'].isin(['three_six_six_days']) & master_cgf_002['scenario'].isin(['bep_ce_scale_up']) & master_cgf_002['treatment_group'].isin(['bep','none']) & master_cgf_002['location'].isin(['India'])  & master_cgf_002['risk'].isin(['wasting']) & master_cgf_002['measure'].isin(['mean'])]
wasting_ce_universal_002
# Out:
#        risk measure         scenario treatment_group mother_status  \
# 64  wasting    mean  bep_ce_scale_up             bep  malnourished
# 66  wasting    mean  bep_ce_scale_up             bep        normal
# 76  wasting    mean  bep_ce_scale_up            none  malnourished
# 78  wasting    mean  bep_ce_scale_up            none        normal
#
#              timepoint    zscore   z_score  start_population   deaths  \
# 64  three_six_six_days  9.476226 -0.523774          13444.32   481.72
# 66  three_six_six_days  9.475539 -0.524461          65971.26  2227.30
# 76  three_six_six_days  9.474769 -0.525231           3492.18   152.76
# 78  three_six_six_days  9.478099 -0.521901          17092.24   618.06
#
#        alive   alive_x_cgf location
# 64  12962.60  -6789.477508    India
# 66  63743.96 -33431.204775    India
# 76   3339.42  -1753.966912    India
# 78  16474.18  -8597.888000    India

# %% [markdown]
# ### WASTING BEP_CE_TARGETED

# %%
# WASTING 29 days

wasting_ce_targeted_002 = master_cgf_002[master_cgf_002['timepoint'].isin(['twenty_nine_days']) & master_cgf_002['scenario'].isin(['bep_ce_targeted_scale_up']) & master_cgf_002['treatment_group'].isin(['bep','mmn','none']) & master_cgf_002['location'].isin(['India'])  & master_cgf_002['risk'].isin(['wasting']) & master_cgf_002['measure'].isin(['mean'])]
wasting_ce_targeted_002
# Out:
#        risk measure                  scenario treatment_group mother_status  \
# 81  wasting    mean  bep_ce_targeted_scale_up             bep  malnourished
# 83  wasting    mean  bep_ce_targeted_scale_up             bep        normal
# 89  wasting    mean  bep_ce_targeted_scale_up             mmn  malnourished
# 91  wasting    mean  bep_ce_targeted_scale_up             mmn        normal
# 93  wasting    mean  bep_ce_targeted_scale_up            none  malnourished
# 95  wasting    mean  bep_ce_targeted_scale_up            none        normal
#
#            timepoint    zscore    z_score  start_population   deaths  \
# 81  twenty_nine_days  9.554054  -0.445946          13444.32   481.72
# 83  twenty_nine_days  0.000000 -10.000000              0.00     0.00
# 89  twenty_nine_days  0.000000 -10.000000              0.00     0.00
# 91  twenty_nine_days  9.552958  -0.447042          65971.26  2249.60
# 93  twenty_nine_days  9.551828  -0.448172           3492.18   152.76
# 95  twenty_nine_days  9.555975  -0.444025          17092.24   618.06
#
#        alive   alive_x_cgf location
# 81  12962.60  -5780.616528    India
# 83      0.00     -0.000000    India
# 89      0.00     -0.000000    India
# 91  63721.66 -28486.254572    India
# 93   3339.42  -1496.636133    India
# 95  16474.18  -7314.939725    India

# %%
# WASTING 366 days

wasting_ce_targeted_002 = master_cgf_002[master_cgf_002['timepoint'].isin(['three_six_six_days']) & master_cgf_002['scenario'].isin(['bep_ce_targeted_scale_up']) & master_cgf_002['treatment_group'].isin(['bep','mmn','none']) & master_cgf_002['location'].isin(['India'])  & master_cgf_002['risk'].isin(['wasting']) & master_cgf_002['measure'].isin(['mean'])]
wasting_ce_targeted_002
# Out:
#        risk measure                  scenario treatment_group mother_status  \
# 80  wasting    mean  bep_ce_targeted_scale_up             bep  malnourished
# 82  wasting    mean  bep_ce_targeted_scale_up             bep        normal
# 88  wasting    mean  bep_ce_targeted_scale_up             mmn  malnourished
# 90  wasting    mean  bep_ce_targeted_scale_up             mmn        normal
# 92  wasting    mean  bep_ce_targeted_scale_up            none  malnourished
# 94  wasting    mean  bep_ce_targeted_scale_up            none        normal
#
#              timepoint    zscore    z_score  start_population   deaths  \
# 80  three_six_six_days  9.476226  -0.523774          13444.32   481.72
# 82  three_six_six_days  0.000000 -10.000000              0.00     0.00
# 88  three_six_six_days  0.000000 -10.000000              0.00     0.00
# 90  three_six_six_days  9.475537  -0.524463          65971.26  2249.60
# 92  three_six_six_days  9.474769  -0.525231           3492.18   152.76
# 94  three_six_six_days  9.478099  -0.521901          17092.24   618.06
#
#        alive   alive_x_cgf location
# 80  12962.60  -6789.477508    India
# 82      0.00     -0.000000    India
# 88      0.00     -0.000000    India
# 90  63721.66 -33419.651458    India
# 92   3339.42  -1753.966912    India
# 94  16474.18  -8597.888000    India

# %% [markdown]
# ## RUN 4 - scenarios HD universal/targeted

# %%
#RUN 4 (bep_ce_universal & targeted)

master_cgf_004 = pd.DataFrame()

for i in list(range(len(output_dirs004))):
    #cgf
    cgf_004 = pd.read_hdf(output_dirs004[i] + 'cgf_z_scores.hdf').reset_index().sort_values(by=['risk','measure','scenario','treatment_group','mother_status'])
    cgf_004 = cgf_004.rename(columns={'value':'zscore'})
    cgf_004['z_score'] = cgf_004['zscore'] - 10
    
    #population
    pop = pd.read_hdf(output_dirs004[i] + 'population.hdf').reset_index()
    pop = pop.where(pop['measure'] == 'total_population').dropna().rename(columns={'value':'start_population'}).drop(columns=['index','measure'])
    
    died = pd.read_hdf(output_dirs004[i] + 'deaths.hdf')
    died = died.groupby(['input_draw', 'scenario','mother_status', 'treatment_group']).sum().rename(columns={'value':'deaths'}).reset_index()
    
    pop = pop.merge(died, right_on=['scenario','treatment_group','mother_status','input_draw'], left_on=['scenario','treatment_group','mother_status','input_draw'])
    
    data = cgf_004.merge(pop, right_on=['scenario','treatment_group','mother_status','input_draw'], left_on=['scenario','treatment_group','mother_status','input_draw'])
    data = data.groupby(['risk','measure','scenario','treatment_group','mother_status']).mean().drop(columns=['input_draw','index']).reset_index() #average over input draws
    data['alive'] = data['start_population'] - data['deaths']
    data['alive_x_cgf'] = data['z_score'] * data['alive'] #cannot use this as weight because the population is the population supplemented (or at birth) whereas the z-score is among alive population at 2 years
    data['location'] = locations[i]
    data['scenario'] = data['scenario'].replace('bep_hd_scale_up', 'bep_hd_scale_up_iii').replace('bep_hd_targeted_scale_up','bep_hd_targeted_scale_up_iii')    
    master_cgf_004 = master_cgf_004.append(data)
    
master_cgf_004.head()
# Out:
#        risk measure             scenario treatment_group mother_status  \
# 0  stunting    mean  bep_hd_scale_up_iii             bep  malnourished
# 1  stunting    mean  bep_hd_scale_up_iii             bep        normal
# 2  stunting    mean  bep_hd_scale_up_iii             ifa  malnourished
# 3  stunting    mean  bep_hd_scale_up_iii             ifa        normal
# 4  stunting    mean  bep_hd_scale_up_iii             mmn  malnourished
#
#       zscore    z_score  start_population   deaths     alive  alive_x_cgf  \
# 0  10.008805   0.008805          13444.32   439.80  13004.52   114.506126
# 1  10.007342   0.007342          65971.26  2000.14  63971.12   469.664947
# 2   0.000000 -10.000000              0.00     0.00      0.00    -0.000000
# 3   0.000000 -10.000000              0.00     0.00      0.00    -0.000000
# 4   0.000000 -10.000000              0.00     0.00      0.00    -0.000000
#
#   location
# 0    India
# 1    India
# 2    India
# 3    India
# 4    India

# %%
#WASTING

wasting004 = master_cgf_004[master_cgf_004['scenario'].isin(['bep_hd_scale_up_iii']) & master_cgf_004['treatment_group'].isin(['bep','none']) & master_cgf_004['location'].isin(['India'])  & master_cgf_004['risk'].isin(['stunting']) & master_cgf_004['measure'].isin(['mean'])]
wasting004
# Out:
#        risk measure             scenario treatment_group mother_status  \
# 0  stunting    mean  bep_hd_scale_up_iii             bep  malnourished
# 1  stunting    mean  bep_hd_scale_up_iii             bep        normal
# 6  stunting    mean  bep_hd_scale_up_iii            none  malnourished
# 7  stunting    mean  bep_hd_scale_up_iii            none        normal
#
#       zscore   z_score  start_population   deaths     alive  alive_x_cgf  \
# 0  10.008805  0.008805          13444.32   439.80  13004.52   114.506126
# 1  10.007342  0.007342          65971.26  2000.14  63971.12   469.664947
# 6   9.719043 -0.280957           3492.18   149.38   3342.80  -939.181567
# 7   9.714250 -0.285750          17092.24   601.70  16490.54 -4712.173295
#
#   location
# 0    India
# 1    India
# 6    India
# 7    India

# %% [markdown]
# # PREVALENCE

# %% [markdown]
# # ================= FEB 2020 model =====================================
#
#  I think the population needs to be updated to those alive

# %%
master_stunting = pd.DataFrame()
master_wasting = pd.DataFrame()

for i in list(range(len(output_dirs))):
    cgf = pd.read_hdf(output_dirs[i] + 'category_counts.hdf').reset_index()
    cgf = (cgf.where(cgf['sex'] == 'male').dropna()
           .groupby(['input_draw','cgf_risk','risk_category','malnourishment_category']).sum()
           .reset_index())
    pop = (cgf.where(cgf['cgf_risk'] == 'stunting').dropna()
          .groupby(['input_draw','malnourishment_category'], as_index=False).sum()
          .rename(columns={'category_counts':'population'}))
    cgf = cgf.where(cgf['risk_category'] == ('cat1' or 'cat2'))
    data = cgf.merge(pop, right_on=['input_draw','malnourishment_category'], 
                     left_on=['input_draw','malnourishment_category'])
    stratified = data.groupby(['input_draw','malnourishment_category','cgf_risk']).sum().reset_index()
    overall = data.groupby(['input_draw','cgf_risk']).sum().reset_index()
    overall['malnourishment_category'] = 'all'
    data = stratified.append(overall)  
    
    stunted = (data.where(data['cgf_risk'] == 'stunting').dropna())
    stunted['percent'] = stunted['category_counts'] / stunted['population']
    stunted = (stunted.groupby(['malnourishment_category']).mean()
              .drop(columns=['input_draw','category_counts','population'])
               .reset_index()) 
    stunted['location'] = locations[i]
    master_stunting = master_stunting.append(stunted)   
    
    wasted = (data.where(data['cgf_risk'] == 'wasting').dropna())
    wasted['percent'] = wasted['category_counts'] / wasted['population']
    wasted = (wasted.groupby(['malnourishment_category']).mean()
              .drop(columns=['input_draw','category_counts','population'])
               .reset_index()) 
    wasted['location'] = locations[i]
    master_wasting = master_wasting.append(wasted)
    master_wasting
# Out:
# /share/code/nicoly/miniconda/envs/gates_bep/lib/python3.6/site-packages/pandas/core/frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)

# %%
master_wasting
# Out:
#   malnourishment_category   percent  location
# 0                     all  0.055677     India
# 1            malnourished  0.142786     India
# 2        not_malnourished  0.038791     India
# 0                     all  0.030601  Pakistan
# 1            malnourished  0.090116  Pakistan
# 2        not_malnourished  0.024041  Pakistan
# 0                     all  0.014787      Mali
# 1            malnourished  0.041370      Mali
# 2        not_malnourished  0.012091      Mali

# %%
master_stunting
# Out:
#   malnourishment_category   percent  location
# 0                     all  0.091158     India
# 1            malnourished  0.200051     India
# 2        not_malnourished  0.069993     India
# 0                     all  0.038440  Pakistan
# 1            malnourished  0.131865  Pakistan
# 2        not_malnourished  0.028073  Pakistan
# 0                     all  0.059996      Mali
# 1            malnourished  0.138289      Mali
# 2        not_malnourished  0.052009      Mali
