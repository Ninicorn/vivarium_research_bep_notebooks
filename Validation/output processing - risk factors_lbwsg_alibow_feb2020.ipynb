# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>")) #makes the display bars longer and spread out 100% across the screen width
# Out:
# <style>.container { width:100% !important; }</style>

# %%
from vivarium import Artifact
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from db_queries import get_ids, get_outputs
import scipy.stats

# %%
output_dirs = ['/ihme/costeffectiveness/results/vivarium_gates_bep/scenarios_fixed/india/2020_02_06_17_37_48/count_data/',
                '/ihme/costeffectiveness/results/vivarium_gates_bep/scenarios_fixed/pakistan/2020_02_06_17_38_45/count_data/',
              '/share/costeffectiveness/results/vivarium_gates_bep/scenarios_fixed/tanzania/2020_02_06_17_39_16/count_data/',
              '/share/costeffectiveness/results/vivarium_gates_bep/scenarios_fixed/mali/2020_02_06_17_38_33/count_data/']

locations = ['India',
            'Pakistan',
            'Tanzania',
            'Mali']

# %% [markdown]
# # 1) LOW BIRTH WEIGHT

# %%
 #exploring the data strcutures for india
    
bw_india = pd.DataFrame()
    
bw_india = pd.read_hdf('/ihme/costeffectiveness/results/vivarium_gates_bep/scenarios_fixed/india/2020_02_06_17_37_48/count_data/' + 'birth_weight.hdf').reset_index().sort_values(by=['input_draw','scenario','treatment_group','mother_status','measure'])
bw_india.head(24)
# Out:
#       index          risk treatment_group mother_status  \
# 0         0  birth_weight             bep  malnourished
# 200     200  birth_weight             bep  malnourished
# 400     400  birth_weight             bep  malnourished
# 600     600  birth_weight             bep        normal
# 800     800  birth_weight             bep        normal
# 1000   1000  birth_weight             bep        normal
# 1200   1200  birth_weight             ifa  malnourished
# 1400   1400  birth_weight             ifa  malnourished
# 1600   1600  birth_weight             ifa  malnourished
# 1800   1800  birth_weight             ifa        normal
# 2000   2000  birth_weight             ifa        normal
# 2200   2200  birth_weight             ifa        normal
# 2400   2400  birth_weight             mmn  malnourished
# 2600   2600  birth_weight             mmn  malnourished
# 2800   2800  birth_weight             mmn  malnourished
# 3000   3000  birth_weight             mmn        normal
# 3200   3200  birth_weight             mmn        normal
# 3400   3400  birth_weight             mmn        normal
# 3600   3600  birth_weight            none  malnourished
# 3800   3800  birth_weight            none  malnourished
# 4000   4000  birth_weight            none  malnourished
# 4200   4200  birth_weight            none        normal
# 4400   4400  birth_weight            none        normal
# 4600   4600  birth_weight            none        normal
#
#                      measure  input_draw  scenario        value
# 0                       mean           3  baseline     0.000000
# 200   proportion_below_2500g           3  baseline     0.000000
# 400                       sd           3  baseline     0.000000
# 600                     mean           3  baseline     0.000000
# 800   proportion_below_2500g           3  baseline     0.000000
# 1000                      sd           3  baseline     0.000000
# 1200                    mean           3  baseline  2732.796612
# 1400  proportion_below_2500g           3  baseline     0.308552
# 1600                      sd           3  baseline   687.126540
# 1800                    mean           3  baseline  3002.006919
# 2000  proportion_below_2500g           3  baseline     0.179073
# 2200                      sd           3  baseline   687.957161
# 2400                    mean           3  baseline     0.000000
# 2600  proportion_below_2500g           3  baseline     0.000000
# 2800                      sd           3  baseline     0.000000
# 3000                    mean           3  baseline     0.000000
# 3200  proportion_below_2500g           3  baseline     0.000000
# 3400                      sd           3  baseline     0.000000
# 3600                    mean           3  baseline  2739.318023
# 3800  proportion_below_2500g           3  baseline     0.306562
# 4000                      sd           3  baseline   675.379240
# 4200                    mean           3  baseline  3003.479346
# 4400  proportion_below_2500g           3  baseline     0.177856
# 4600                      sd           3  baseline   684.265808

# %%
pop_india = pd.read_hdf('/ihme/costeffectiveness/results/vivarium_gates_bep/scenarios_fixed/india/2020_02_06_17_37_48/count_data/' + 'population.hdf').reset_index().sort_values(by=['input_draw','scenario','treatment_group','mother_status'])
pop_india.head(13)
# Out:
#       index treatment_group mother_status                     measure  \
# 0         0             all           all            total_population
# 200     200             all           all       total_population_dead
# 400     400             all           all     total_population_living
# 600     600             all           all    total_population_tracked
# 800     800             all           all  total_population_untracked
# 1000   1000             bep  malnourished            total_population
# 1200   1200             bep        normal            total_population
# 1400   1400             ifa  malnourished            total_population
# 1600   1600             ifa        normal            total_population
# 1800   1800             mmn  malnourished            total_population
# 2000   2000             mmn        normal            total_population
# 2200   2200            none  malnourished            total_population
# 2400   2400            none        normal            total_population
#
#       input_draw  scenario     value
# 0              3  baseline  100000.0
# 200            3  baseline    2649.0
# 400            3  baseline   97351.0
# 600            3  baseline  100000.0
# 800            3  baseline       0.0
# 1000           3  baseline       0.0
# 1200           3  baseline       0.0
# 1400           3  baseline    5881.0
# 1600           3  baseline   29235.0
# 1800           3  baseline       0.0
# 2000           3  baseline       0.0
# 2200           3  baseline   10921.0
# 2400           3  baseline   53963.0

# %%
pop_india.measure.unique()
# Out:
# array(['total_population', 'total_population_dead',
#        'total_population_living', 'total_population_tracked',
#        'total_population_untracked'], dtype=object)

# %%
master_bw = pd.DataFrame()

for i in list(range(len(output_dirs))):
    bw = pd.read_hdf(output_dirs[i] + 'birth_weight.hdf').reset_index().sort_values(by=['risk','measure','scenario','treatment_group','mother_status'])
    pop = pd.read_hdf(output_dirs[i] + 'population.hdf').reset_index()
    pop = pop.where(pop['measure'] == 'total_population').dropna().rename(columns={'value':'total_population'}).drop(columns=['index','measure'])
    data = bw.merge(pop, right_on=['scenario','treatment_group','mother_status','input_draw'], left_on=['scenario','treatment_group','mother_status','input_draw'])
    data = data.groupby(['risk','measure','scenario','treatment_group','mother_status']).mean().drop(columns=['input_draw','index']).reset_index()
    data['weighted_value'] = data['value'] * data['total_population']
    data['location'] = locations[i]
    master_bw = master_bw.append(data)
    
master_bw.head()
# Out:
#            risk measure  scenario treatment_group mother_status        value  \
# 0  birth_weight    mean  baseline             bep  malnourished     0.000000
# 1  birth_weight    mean  baseline             bep        normal     0.000000
# 2  birth_weight    mean  baseline             ifa  malnourished  2684.283214
# 3  birth_weight    mean  baseline             ifa        normal  3038.537322
# 4  birth_weight    mean  baseline             mmn  malnourished     0.000000
#
#    total_population  weighted_value location
# 0              0.00    0.000000e+00    India
# 1              0.00    0.000000e+00    India
# 2           5770.54    1.548976e+07    India
# 3          28261.14    8.587253e+07    India
# 4              0.00    0.000000e+00    India

# %%
india_bw = master_bw[master_bw['location'].isin(['India']) & master_bw['measure'].isin(['mean']) & master_bw['scenario'].isin(['baseline']) & master_bw['treatment_group'].isin(['ifa', 'none'])]
india_bw
# Out:
#            risk measure  scenario treatment_group mother_status        value  \
# 2  birth_weight    mean  baseline             ifa  malnourished  2684.283214
# 3  birth_weight    mean  baseline             ifa        normal  3038.537322
# 6  birth_weight    mean  baseline            none  malnourished  2683.328356
# 7  birth_weight    mean  baseline            none        normal  3038.579482
#
#    total_population  weighted_value location
# 2           5770.54    1.548976e+07    India
# 3          28261.14    8.587253e+07    India
# 6          11165.96    2.996194e+07    India
# 7          54802.36    1.665213e+08    India

# %%
master_bw['scenario'].unique()
# Out:
# array(['baseline', 'bep_scale_up', 'bep_targeted_scale_up',
#        'mmn_scale_up'], dtype=object)

# %%
master_bw['treatment_group'].unique()
# Out:
# array(['bep', 'ifa', 'mmn', 'none'], dtype=object)

# %%
#mean birthweight by country and treatment groups
(master_bw.where(master_bw['treatment_group'] == 'ifa')
         .where(master_bw['scenario'] == 'baseline')
         .where(master_bw['risk'] == 'birth_weight')
         .where(master_bw['measure'] == 'mean').dropna())
# Out:
#            risk measure  scenario treatment_group mother_status        value  \
# 2  birth_weight    mean  baseline             ifa  malnourished  2684.283214
# 3  birth_weight    mean  baseline             ifa        normal  3038.537322
# 2  birth_weight    mean  baseline             ifa  malnourished  2593.444746
# 3  birth_weight    mean  baseline             ifa        normal  2943.289694
# 2  birth_weight    mean  baseline             ifa  malnourished  3148.812417
# 3  birth_weight    mean  baseline             ifa        normal  3358.446589
# 2  birth_weight    mean  baseline             ifa  malnourished  2740.943104
# 3  birth_weight    mean  baseline             ifa        normal  3029.551470
#
#    total_population  weighted_value  location
# 2           5770.54    1.548976e+07     India
# 3          28261.14    8.587253e+07     India
# 2           2671.18    6.927558e+06  Pakistan
# 3          22047.76    6.489294e+07  Pakistan
# 2           2014.98    6.344794e+06  Tanzania
# 3          18955.92    6.366244e+07  Tanzania
# 2           2423.88    6.643717e+06      Mali
# 3          20875.32    6.324286e+07      Mali

# %%
#get birthweight mean by country and mom status in baseline scenario

#mean birthweight by country and treatment groups
baseline_bw = (master_bw.where(master_bw['treatment_group'] == 'ifa' | master_bw['treatment_group'] == 'none')
                        .where(master_bw['scenario'] == 'baseline')
                        .where(master_bw['risk'] == 'birth_weight')
                        .where(master_bw['measure'] == 'mean').dropna())

baseline_bw
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /share/code/nicoly/miniconda/envs/gates_bep/lib/python3.6/site-packages/pandas/core/ops.py in na_op(x, y)
#    1788         try:
# -> 1789             result = op(x, y)
#    1790         except TypeError:
#
# /share/code/nicoly/miniconda/envs/gates_bep/lib/python3.6/site-packages/pandas/core/ops.py in ror_(left, right)
#     190 def ror_(left, right):
# --> 191     return operator.or_(right, left)
#     192
#
# TypeError: unsupported operand type(s) for |: 'str' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# /share/code/nicoly/miniconda/envs/gates_bep/lib/python3.6/site-packages/pandas/core/ops.py in na_op(x, y)
#    1803                 try:
# -> 1804                     result = libops.scalar_binop(x, y, op)
#    1805                 except (TypeError, ValueError, AttributeError,
#
# pandas/_libs/ops.pyx in pandas._libs.ops.scalar_binop()
#
# /share/code/nicoly/miniconda/envs/gates_bep/lib/python3.6/site-packages/pandas/core/ops.py in ror_(left, right)
#     190 def ror_(left, right):
# --> 191     return operator.or_(right, left)
#     192
#
# TypeError: unsupported operand type(s) for |: 'bool' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-b00493f889a1> in <module>
#       2
#       3 #mean birthweight by country and treatment groups
# ----> 4 baseline_bw = (master_bw.where(master_bw['treatment_group'] == 'ifa' | master_bw['treatment_group'] == 'none')
#       5                         .where(master_bw['scenario'] == 'baseline')
#       6                         .where(master_bw['risk'] == 'birth_weight')
#
# /share/code/nicoly/miniconda/envs/gates_bep/lib/python3.6/site-packages/pandas/core/ops.py in wrapper(self, other)
#    1848         filler = (fill_int if is_self_int_dtype and is_other_int_dtype
#    1849                   else fill_bool)
# -> 1850         res_values = na_op(self.values, ovalues)
#    1851         unfilled = self._constructor(res_values,
#    1852                                      index=self.index, name=res_name)
#
# /share/code/nicoly/miniconda/envs/gates_bep/lib/python3.6/site-packages/pandas/core/ops.py in na_op(x, y)
#    1808                                     "with a scalar of type [{typ}]"
#    1809                                     .format(dtype=x.dtype,
# -> 1810                                             typ=type(y).__name__))
#    1811
#    1812         return result
#
# TypeError: cannot compare a dtyped [object] array with a scalar of type [bool]

# %%
master_bw.where(master_bw['measure'] == 'proportion_below_2500g').dropna().head()

# %%
#PREVALENCE OF LBW

stratified = master_bw.groupby(['location','measure','scenario','mother_status']).sum()
stratified['weighted_average'] = stratified['weighted_value'] / stratified['total_population']
stratified = stratified.reset_index()
stratified = stratified.where(stratified['measure'] == 'proportion_below_2500g').where(stratified['scenario'] == 'baseline').dropna()
overall = master_bw.groupby(['location','measure','scenario']).sum()
overall['weighted_average'] = overall['weighted_value'] / overall['total_population']
overall = overall.reset_index()
overall = overall.where(overall['measure'] == 'proportion_below_2500g').where(overall['scenario'] == 'baseline').dropna()
overall['mother_status'] = 'all'
data = stratified.append(overall)
data = data.sort_values(by='location')

data

# %%
# bar width
barWidth = 0.2

# bar heights
overall = data['weighted_average'].where(data['mother_status'] == 'all').dropna()
normal = data['weighted_average'].where(data['mother_status'] == 'normal').dropna()
malnourished = data['weighted_average'].where(data['mother_status'] == 'malnourished').dropna()

# bar positions
a = np.arange(len(overall))
b = [x + barWidth for x in a]
c = [x + barWidth for x in b]

# plot 
plt.bar(a, overall, width=barWidth)
plt.bar(b, normal, width=barWidth)
plt.bar(c, malnourished, width=barWidth)
plt.xticks([r + barWidth for r in range(len(normal))], np.unique(data['location']))
plt.legend(['Overall','BMI > 18.5','BMI < 18.5'])
plt.title('Prevalence of Low Birth Weight (<2500 grams)')
plt.ylabel('Proportion')

# %%
# plot baseline mean birth weight stratified by maternal malnourishment

stratified = master_bw.groupby(['location','measure','scenario','mother_status']).sum()
stratified['weighted_average'] = stratified['weighted_value'] / stratified['total_population']
stratified = stratified.reset_index()
stratified = stratified.where(stratified['measure'] == 'mean').where(stratified['scenario'] == 'baseline').dropna()
overall = master_bw.groupby(['location','measure','scenario']).sum()
overall['weighted_average'] = overall['weighted_value'] / overall['total_population']
overall = overall.reset_index()
overall = overall.where(overall['measure'] == 'mean').where(overall['scenario'] == 'baseline').dropna()
overall['mother_status'] = 'all'
data = stratified.append(overall)
data = data.sort_values(by='location')

# %%
data

# %%
# bar width
barWidth = 0.2

# bar heights
overall = data['weighted_average'].where(data['mother_status'] == 'all').dropna()
normal = data['weighted_average'].where(data['mother_status'] == 'normal').dropna()
malnourished = data['weighted_average'].where(data['mother_status'] == 'malnourished').dropna()

# bar positions
a = np.arange(len(overall))
b = [x + barWidth for x in a]
c = [x + barWidth for x in b]

# plot 
plt.bar(a, overall, width=barWidth)
plt.bar(b, normal, width=barWidth)
plt.bar(c, malnourished, width=barWidth)
plt.xticks([r + barWidth for r in range(len(normal))], np.unique(data['location']))
plt.legend(['Overall','BMI > 18.5','BMI < 18.5'])
plt.title('Baseline Mean Birthweight')
plt.ylabel('Birth Weight (grams)')
plt.ylim(0,4200)

# %%
master_bw = pd.DataFrame()

for i in list(range(len(output_dirs))):
    bw = pd.read_hdf(output_dirs[i] + 'birth_weight.hdf').reset_index().sort_values(by=['risk','measure','scenario','treatment_group','mother_status'])
    pop = pd.read_hdf(output_dirs[i] + 'population.hdf').reset_index()
    pop = pop.where(pop['measure'] == 'total_population').dropna().rename(columns={'value':'total_population'}).drop(columns=['index','measure'])
    data = bw.merge(pop, right_on=['scenario','treatment_group','mother_status','input_draw'], left_on=['scenario','treatment_group','mother_status','input_draw'])
    data = data.groupby(['risk','measure','scenario','treatment_group','mother_status']).mean().drop(columns=['input_draw','index']).reset_index()
    data['weighted_value'] = data['value'] * data['total_population']
    data['location'] = locations[i]
    master_bw = master_bw.append(data)
    
master_bw.head()

# %% [markdown]
# # 2) CHILD GROWTH FAILURE

# %%
cgf = pd.read_hdf('/share/costeffectiveness/results/vivarium_gates_bep/malnutrition/india/2020_02_05_03_02_13/count_space/category_counts.hdf').reset_index()
cgf = cgf.where(cgf['sex'] == 'male').dropna()
cgf = cgf.groupby(['input_draw','cgf_risk','risk_category','malnourishment_category']).sum().reset_index()
pop = pd.read_hdf('/share/costeffectiveness/results/vivarium_gates_bep/malnutrition/india/2020_02_05_03_02_13/count_space/birth_prevalence.hdf').reset_index()
pop = pop.groupby(['input_draw','malnourishment_category']).sum().reset_index().rename(columns={'birth_prevalence':'total_population'})
data = cgf.merge(pop, right_on=['input_draw','malnourishment_category'], left_on=['input_draw','malnourishment_category'])
data['percent'] = data['category_counts'] / data['total_population'] 
data.head()

# %%
pop = pd.read_hdf('/share/costeffectiveness/results/vivarium_gates_bep/malnutrition/india/2020_02_05_03_02_13/count_space/birth_prevalence.hdf').reset_index()
#pop = pop.groupby(['input_draw','malnourishment_category']).sum().reset_index().rename(columns={'birth_prevalence':'total_population'})
pop.where(pop['input_draw'] == 29.0).dropna()

# %%
np.unique(pop['birth_state'])

# %%
pop = pd.read_hdf('/share/costeffectiveness/results/vivarium_gates_bep/malnutrition/india/2020_02_05_03_02_13/count_space/population.hdf').reset_index()
pop.head()
